# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy as sqla

# %%
pd.read_csv('../partner_eda/partner_project_evals.csv')
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_14568\3778154642.py:1: DtypeWarning: Columns (0,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../partner_eda/partner_project_evals.csv')
#       Child ID Gender Date of Birth Location - Sub Level 1 contract number  \
# 0        44879      F     9/27/2022              Southwest      contract 3
# 1        47795      F    12/23/2020      Greater Nashville      contract 2
# 2        54340      M     6/22/2021        First Tennessee      contract 1
# 3        54344      F      3/7/2022    Southeast Tennessee      contract 1
# 4        54515      M     11/4/2021          Memphis Delta      contract 3
# ...        ...    ...           ...                    ...             ...
# 23942  SP03287      F     9/25/2023          Memphis Delta      contract 3
# 23943  SP03288      F     5/18/2021          South Central      contract 2
# ...
