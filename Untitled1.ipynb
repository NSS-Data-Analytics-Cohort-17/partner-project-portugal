# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy as sqla

# %%
evals = pd.read_csv('../partner_eda/sheet_eval.csv')
evals.head()
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_22892\1209382779.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   evals = pd.read_csv('../partner_eda/sheet_eval.csv')
#   Child ID Gender Date of Birth Location - Sub Level 1 contract number  \
# 0    44879      F     9/27/2022              Southwest      contract 3
# 1    47795      F    12/23/2020      Greater Nashville      contract 2
# 2    54340      M     6/22/2021        First Tennessee      contract 1
# 3    54344      F      3/7/2022    Southeast Tennessee      contract 1
# 4    54515      M     11/4/2021          Memphis Delta      contract 3
#
#                   Program Label  Adaptive Sum of Scaled Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# ...

# %%
evals = evals.drop_duplicates()
evals.head()
# Out:
#   Child ID Gender Date of Birth Location - Sub Level 1 contract number  \
# 0    44879      F     9/27/2022              Southwest      contract 3
# 1    47795      F    12/23/2020      Greater Nashville      contract 2
# 2    54340      M     6/22/2021        First Tennessee      contract 1
# 3    54344      F      3/7/2022    Southeast Tennessee      contract 1
# 4    54515      M     11/4/2021          Memphis Delta      contract 3
#
#                   Program Label  Adaptive Sum of Scaled Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                             85.0                       16
# ...

# %%
evals.dtypes
# Out:
# Child ID                                      object
# Gender                                        object
# Date of Birth                                 object
# Location - Sub Level 1                        object
# contract number                               object
#                                               ...
# Cognitive-Perception and Concepts CSS        float64
# Cognitive-Perception and Concepts CSS 90%     object
# Cognitive-Perception and Concepts Z-Score     object
# Cognitive-Perception and Concepts T-Score    float64
# Cognitive-Perception and Concepts NCE         object
# Length: 210, dtype: object
