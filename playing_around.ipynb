# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy as sqla
import numpy as np

# %% [markdown]
# I want to write some user defined functions

# %%
list = ['me', 2, 'dislike', 14]

for item in list:
    print(type(item))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %%
def area_triangle(base,height):
    area = 0.5 * base * height
    print(area)

area_triangle(3,6)
# Out:
# 9.0

# %%
evals = pd.read_csv('../partner_eda/partner_project_evals.csv')
evals
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_35952\2331705836.py:1: DtypeWarning: Columns (0,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   evals = pd.read_csv('../partner_eda/partner_project_evals.csv')
#       Child ID Gender Date of Birth Location - Sub Level 1 contract number  \
# 0        44879      F     9/27/2022              Southwest      contract 3
# 1        47795      F    12/23/2020      Greater Nashville      contract 2
# 2        54340      M     6/22/2021        First Tennessee      contract 1
# 3        54344      F      3/7/2022    Southeast Tennessee      contract 1
# 4        54515      M     11/4/2021          Memphis Delta      contract 3
# ...        ...    ...           ...                    ...             ...
# 23942  SP03287      F     9/25/2023          Memphis Delta      contract 3
# 23943  SP03288      F     5/18/2021          South Central      contract 2
# ...

# %%
evals.columns
# Out:
# Index(['Child ID', 'Gender', 'Date of Birth', 'Location - Sub Level 1',
#        'contract number', 'Program Label', 'Adaptive Sum of Scaled Scores',
#        'Adaptive Developmental Quotient', 'Adaptive Percentile Rank',
#        'Adaptive 95% Confidence Interval',
#        ...
#        'Code 1', 'Code 2', 'Code 3', 'Code 4', 'Code 5', 'Code 6', 'Code 7',
#        'Code 8', 'Code 9', 'Code 10'],
#       dtype='object', length=220)

# %%
columns = ['Child ID', 'Gender', 'Date of Birth', 'Location - Sub Level 1',
       'contract number', 'Program Label', 'Adaptive Sum of Scaled Scores',
       'Adaptive Developmental Quotient', 'Adaptive Percentile Rank',
       'Adaptive 95% Confidence Interval']

for column in columns:
    if column.contains('Interval'):
        print('interval')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 7
#       1 columns = ['Child ID', 'Gender', 'Date of Birth', 'Location - Sub Level 1',
#       2        'contract number', 'Program Label', 'Adaptive Sum of Scaled Scores',
#       3        'Adaptive Developmental Quotient', 'Adaptive Percentile Rank',
#       4        'Adaptive 95% Confidence Interval']
#       6 for column in columns:
# ----> 7     if column.contains('Interval'):
#       8         print('interval')
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
starwars_df = pd.read_csv("C:\\Users\\plann\\Documents\\Nashville Software School\\Python\\data\\starwars(1).csv")
starwars_df
# Out:
#                      name height  height order  mass hair_color   skin_color  \
# 0                    Yoda     66           1.0  17.0      white        green
# 1           Ratts Tyerell     79           2.0  15.0       none   grey, blue
# 2   Wicket Systri Warrick     88           3.0  20.0      brown        brown
# 3                Dud Bolt     94           4.0  45.0       none   blue, grey
# 4                   R2-D2     96           5.0  32.0        NaN  white, blue
# ..                    ...    ...           ...   ...        ...          ...
# 85                    BB8    NaN          86.0   NaN       none         none
# 86         Captain Phasma    NaN          87.0   NaN    unknown      unknown
# 87                    NaN    NaN           NaN   NaN        NaN          NaN
# 88                    NaN    NaN           NaN   NaN        NaN          NaN
# 89                    NaN  FALSE           NaN   NaN        NaN          NaN
#
# ...

# %%
name_list = starwars_df['name'].to_list()
name_list
# Out:
# ['Yoda',
#  'Ratts\xa0Tyerell',
#  'Wicket\xa0Systri\xa0Warrick',
#  'Dud\xa0Bolt',
#  'R2-D2',
#  'R4-P17',
#  'R5-D4',
#  'Sebulba',
#  'Gasgano',
#  'Watto',
#  'Leia\xa0Organa',
#  'Mon\xa0Mothma',
#  'Cordé',
#  'Nien\xa0Nunb',
#  'Shmi\xa0Skywalker',
#  'Ben\xa0Quadinaros',
#  'Beru\xa0Whitesun\xa0lars',
#  'Dormé',
#  'Padmé\xa0Amidala',
#  'Barriss\xa0Offee',
#  'C-3PO',
#  'Jocasta\xa0Nu',
#  'Zam\xa0Wesell',
#  'Wedge\xa0Antilles',
#  'Palpatine',
#  'Finis\xa0Valorum',
#  'Luminara\xa0Unduli',
#  'Eeth\xa0Koth',
#  'Luke\xa0Skywalker',
#  'Greedo',
#  'Jabba\xa0Desilijic\xa0Tiure',
#  'Lobot',
#  'Darth\xa0Maul',
#  'Lando\xa0Calrissian',
#  'Owen\xa0Lars',
#  'Ayla\xa0Secura',
#  'Shaak\xa0Ti',
#  'Sly\xa0Moore',
#  'Wilhuff\xa0Tarkin',
#  'Han\xa0Solo',
#  'Jek\xa0Tono\xa0Porkins',
#  'Ackbar',
#  'Bib\xa0Fortuna',
#  'Obi-Wan\xa0Kenobi',
#  'Biggs\xa0Darklighter',
#  'Boba\xa0Fett',
#  'Ric\xa0Olié',
#  'Quarsh\xa0Panaka',
#  'Cliegg\xa0Lars',
# ...

# %%
for name in name_list:
    if 'Skywalker' in name: #is regex needed here?
        print('strong character')
# Out:
# strong character
# strong character
# strong character
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 for name in name_list:
# ----> 2     if 'Skywalker' in name: #is regex needed here?
#       3         print('strong character')
#
# TypeError: argument of type 'float' is not iterable

# %%
x = starwars['variable']
